# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy as sc
import math

# %%
#########################################
#### convert gene name to ENSEMBL ID ####
#########################################

dic = pd.read_csv('W:\lab_winter\private\Experiments\Matthias_MB\\2018\MB18_56 QuantSeq merge analysis\\data\\ENStoGeneName.txt', sep="\t")
dic.columns = ['geneID', 'gene_name']
dic = dic.set_index('gene_name')


### this is only the control sets, the actual SE sets were converted earlier (TTseq plots file)
geneset_df = pd.read_csv('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\Hct116_CRC_TTseq_1h2hDMSO.txt', sep="\t")

# %%
geneset_df
# Out:
#     GenRes_204_SE GenRes_21_TF GenRes_14_autoreg_3-3 GenRes_7_autoreg_6-6  \
# 0           ABCC2         ETV4                  ETV4                FOSL1
# 1          ABHD10        FOSL1                 FOSL1                HMGA2
# 2            ACTB         HES1                 HMGA2                 JUND
# 3           ACTN4        HIF1A                  JUND                  MYC
# 4            AGRN        HMGA2                  KLF6                  SP1
# 5           AHNAK         JUND                   MNT               SREBF1
# 6          AKT1S1         KLF6                   MYC               TCF7L2
# 7         ALDH3B1          MNT                 SMAD3                  NaN
# 8         ANKRD40          MYC                   SP1                  NaN
# 9            AREG      ONECUT3                SREBF1                  NaN
# 10       ARHGAP12        SMAD3                TCF7L2                  NaN
# 11       ARHGAP18          SP1                 TGIF1                  NaN
# ...

# %%
### 290 SE control genes
control_SE_genes = geneset_df['control_SE_all'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(control_SE_genes)) != len(dic.loc[control_SE_genes].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[control_SE_genes].index.tolist():
        if dic.loc[control_SE_genes].index.tolist().count(x) > 1:
            print x

#dic.loc[control_SE_genes].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\control_290_SE_genes.xlsx')
# Out:
# C:\Users\mjaeger\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:5: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """
# C:\Users\mjaeger\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:7: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   import sys
# C:\Users\mjaeger\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# ...

# %%
### 23 TF control genes
control_TF_genes = geneset_df['control_TF_all'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(control_TF_genes)) != len(dic.loc[control_TF_genes].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[control_TF_genes].index.tolist():
        if dic.loc[control_TF_genes].index.tolist().count(x) > 1:
            print x

#dic.loc[control_TF_genes].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\control_23_TF_genes.xlsx')
# Out:
# genesets don't match! Following genes are duplicates:
# TAS2R14
# TAS2R14
# TAS2R14

# %%
### 23 TF control sampled from TFs only
control_TF_onlyTFs = geneset_df['control_TF_onlyTFs'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(control_TF_onlyTFs)) != len(dic.loc[control_TF_onlyTFs].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[control_TF_onlyTFs].index.tolist():
        if dic.loc[control_TF_onlyTFs].index.tolist().count(x) > 1:
            print x

#dic.loc[control_TF_onlyTFs].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\control_23_TF_onlyTFs.xlsx')
# Out:
# genesets don't match! Following genes are duplicates:
# ZNF35
# ZNF35
# ZNF251
# ZNF251

# %%
### 17 autoreg TFs control sampled from all genes
control_CRC_all = geneset_df['control_CRC_all'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(control_CRC_all)) != len(dic.loc[control_CRC_all].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[control_CRC_all].index.tolist():
        if dic.loc[control_CRC_all].index.tolist().count(x) > 1:
            print x

#dic.loc[control_CRC_all].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\control_17_autoregTF_genes.xlsx')
# Out:
# genesets don't match! Following genes are duplicates:
# PRRC2A
# PRRC2A
# PRRC2A
# PRRC2A
# PRRC2A
# PRRC2A
# PRRC2A
# CLIC1
# CLIC1
# CLIC1
# CLIC1
# CLIC1
# CLIC1
# CLIC1

# %%
### 17 autoreg TFs control sampled from TFs only
control_CRC_onlyTFs = geneset_df['control_CRC_onlyTFs'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(control_CRC_onlyTFs)) != len(dic.loc[control_CRC_onlyTFs].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[control_CRC_onlyTFs].index.tolist():
        if dic.loc[control_CRC_onlyTFs].index.tolist().count(x) > 1:
            print x

#dic.loc[control_CRC_onlyTFs].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\control_17_autoregTF_onlyTFs.xlsx')

# %%
####################################
#### load in all the gene lists ####
####################################

MolCell_SE_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\MolCell_290_SE_genes.xlsx')
MolCell_TF_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\MolCell_23_TF_genes.xlsx')
MolCell_autoreg3_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\MolCell_17_autoreg_3+3_genes.xlsx')
SE_control_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\control_290_SE_genes.xlsx')
TF_control_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\control_23_TF_genes.xlsx')
TF_control_onlyTFs = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\control_23_TF_onlyTFs.xlsx')
CRC_control_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\control_17_autoregTF_genes.xlsx')
CRC_control_onlyTFs = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\control_17_autoregTF_onlyTFs.xlsx')

# %%
######################################
#### grep genes from DEseq tables ####
######################################
# DEseq2 dataframe
DEseq_TT_1h_df = pd.read_csv('T:\\groups\\lab_winter\\martin\\MJ-20-5_Cramer_lab\\differential.expression.estimates_1h_HCT116.txt', sep="\t")

##### grep autoreg CRC genes #####
CRC_DEseq = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(MolCell_autoreg3_genes.geneID.tolist()), na=False)]
TF_DEseq = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(MolCell_TF_genes.geneID.tolist()), na=False)]
SE_DEseq = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(MolCell_SE_genes.geneID.tolist()), na=False)]
SE_control_DEseq = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(SE_control_genes.geneID.tolist()), na=False)]
TF_control_genes_DEseq = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(TF_control_genes.geneID.tolist()), na=False)]
TF_control_onlyTFs_DEseq = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(TF_control_onlyTFs.geneID.tolist()), na=False)]
CRC_control_genes_DEseq = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(CRC_control_genes.geneID.tolist()), na=False)]
CRC_control_onlyTFs_DEseq = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(CRC_control_onlyTFs.geneID.tolist()), na=False)]

##### now manually take the log2FC and -log10q to the boxes figure

# %%
print -1*np.log10(DEseq_TT_1h_df.padj.median())
DEseq_TT_1h_df.describe()
# Out:
# 1.7126308827187209
#               start           end        length       baseMean  \
# count  2.162900e+04  2.162900e+04  2.162900e+04   21629.000000
# mean   7.455657e+07  7.461773e+07  6.116138e+04    2601.831586
# std    5.534617e+07  5.535199e+07  1.202342e+05    7064.398349
# min    1.155500e+04  1.409000e+04  7.000000e+01       0.083333
# 25%    3.179118e+07  3.186122e+07  9.093000e+03       6.291667
# 50%    6.114160e+07  6.122930e+07  2.392600e+04     236.250000
# 75%    1.107326e+08  1.108703e+08  6.216900e+04    2005.791667
# max    2.489062e+08  2.489191e+08  2.304636e+06  229697.666667
#
#        log2FoldChange         lfcSE          stat         pvalue  \
# count    2.162900e+04  21629.000000  2.162900e+04   2.162900e+04
# mean    -4.466345e-01      0.544287 -1.871064e+00   3.155844e-01
# std      6.240803e-01      0.429507  2.134977e+00   3.653477e-01
# min     -4.565800e+00      0.100019 -2.487535e+01  1.375586e-136
# ...

# %%
##############################################
#### generate CRC network cytoscape input ####
##############################################
# first the node interactions as SIF format (columns: source | interaction | target | no_of_motifs):
motif_df = pd.read_csv('S:\\lab_winter\\martin\\Mediator_CRC\\networks\\HCT116_MolCell_Number_of_motifs_for_17autoreg_TFs.txt', sep="\t")
motif_df.Number_of_SEs = "pp"

#motif_df.to_csv('S:\\lab_winter\\martin\\Mediator_CRC\\networks\\HCT116_MolCell_Number_of_motifs_for_17autoreg_TFs.sif', sep="\t", header=False)


# now node attributes:
CRC_annotated = pd.DataFrame(columns=MolCell_autoreg3_genes.columns)
for gene in MolCell_autoreg3_genes.geneID: #["ENSG00000070476", "ENSG00000136997"]:
    row = CRC_DEseq[CRC_DEseq.gene_id.str.contains(gene)]
    row.loc[row.index, 'single_ID'] = gene
    row.loc[row.index, 'gene_name'] = MolCell_autoreg3_genes.loc[MolCell_autoreg3_genes.geneID.str.contains(gene), 'gene_name'].values[0]
    CRC_annotated = CRC_annotated.append(row, sort=False)

CRC_annotated.to_csv('S:\\lab_winter\\martin\\Mediator_CRC\\networks\\HCT116_MolCell_17autoreg_TFs_network_node_attributes_final.txt', sep="\t")

# %%
motif_df
# Out:
#     TF_name Number_of_SEs TG_name  Number_of_motif_occurence
# 0    ARID3A            pp  ARID3A                        149
# 1    ARID3A            pp    ELF3                         71
# 2    ARID3A            pp   FOSL1                         21
# 3    ARID3A            pp   GLIS2                         96
# 4    ARID3A            pp    JUNB                        181
# 5    ARID3A            pp    JUND                        298
# 6    ARID3A            pp   MEF2D                         55
# 7    ARID3A            pp  MLXIPL                         35
# 8    ARID3A            pp     MNT                         10
# 9    ARID3A            pp     MYC                         44
# 10   ARID3A            pp    SOX9                         39
# 11   ARID3A            pp     SP1                        199
# 12   ARID3A            pp  SREBF1                         44
# 13   ARID3A            pp  TCF7L2                         30
# ...

# %%
# DEseq2 dataframe
DEseq_TT_1h_df = pd.read_csv('T:\\groups\\lab_winter\\martin\\MJ-20-5_Cramer_lab\\differential.expression.estimates_1h_HCT116.txt', sep="\t")

# %%
DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('ENSG00000230685', na=False)]
# Out:
# Empty DataFrame
# Columns: [chr, strand, start, end, type, source, length, id, baseMean, log2FoldChange, lfcSE, stat, pvalue, padj, gene_id, transcript_id]
# Index: []
