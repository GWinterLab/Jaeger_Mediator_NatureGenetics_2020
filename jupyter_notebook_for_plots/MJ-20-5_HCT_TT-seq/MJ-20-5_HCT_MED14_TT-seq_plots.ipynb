# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy as sc
import math

plots_dir = 'S:\\lab_winter\\martin\\MJ-20-5\\plots\\' # directory for output plots

# %%
#########################################
#### convert gene name to ENSEMBL ID ####
#########################################

dic = pd.read_csv('W:\lab_winter\private\Experiments\Matthias_MB\\2018\MB18_56 QuantSeq merge analysis\\data\\ENStoGeneName.txt', sep="\t")
dic.columns = ['geneID', 'gene_name']
dic = dic.set_index('gene_name')

geneset_df = pd.read_csv('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\Hct116_CRC_TTseq_1h2hDMSO.txt', sep="\t")

# %%
### 204 GenRes SEs
GenRes_SE_genes = geneset_df['GenRes_204_SE'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(GenRes_SE_genes)) != len(dic.loc[GenRes_SE_genes].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[GenRes_SE_genes].index.tolist():
        if dic.loc[GenRes_SE_genes].index.tolist().count(x) > 1:
            print x

#dic.loc[GenRes_SE_genes].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\GenRes_204_SE_genes.xlsx')
# Out:
# C:\Users\mjaeger\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:5: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """
# C:\Users\mjaeger\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:7: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   import sys
# C:\Users\mjaeger\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# ...

# %%
### 21 GenRes TFs
GenRes_TF_genes = geneset_df['GenRes_21_TF'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(GenRes_TF_genes)) != len(dic.loc[GenRes_TF_genes].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[GenRes_TF_genes].index.tolist():
        if dic.loc[GenRes_TF_genes].index.tolist().count(x) > 1:
            print x

#dic.loc[GenRes_TF_genes].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\GenRes_21_TF_genes.xlsx')

# %%
### 14 GenRes autoreg 3+3
GenRes_autoreg3_genes = geneset_df['GenRes_14_autoreg_3-3'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(GenRes_autoreg3_genes)) != len(dic.loc[GenRes_autoreg3_genes].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[GenRes_autoreg3_genes].index.tolist():
        if dic.loc[GenRes_autoreg3_genes].index.tolist().count(x) > 1:
            print x

#dic.loc[GenRes_autoreg3_genes].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\GenRes_14_autoreg_3+3_genes.xlsx')

# %%
### 7 GenRes autoreg 6+6
GenRes_autoreg6_genes = geneset_df['GenRes_7_autoreg_6-6'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(GenRes_autoreg6_genes)) != len(dic.loc[GenRes_autoreg6_genes].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[GenRes_autoreg6_genes].index.tolist():
        if dic.loc[GenRes_autoreg6_genes].index.tolist().count(x) > 1:
            print x

#dic.loc[GenRes_autoreg6_genes].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\GenRes_7_autoreg_6+6_genes.xlsx')

# %%
### 290 MolCell SEs
MolCell_SE_genes = geneset_df['MolCell_290_SE'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(MolCell_SE_genes)) != len(dic.loc[MolCell_SE_genes].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[MolCell_SE_genes].index.tolist():
        if dic.loc[MolCell_SE_genes].index.tolist().count(x) > 1:
            print x

#dic.loc[MolCell_SE_genes].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\MolCell_290_SE_genes.xlsx')
# Out:
# genesets don't match! Following genes are duplicates:
# ACTN4
# ACTN4
# C16orf45
# C16orf45
# DDR1
# DDR1
# DDR1
# DDR1
# DDR1
# DDR1
# DDR1
# ELFN2
# ELFN2
# FAM83H
# FAM83H
# GLIS2
# GLIS2
# HSPA1B
# HSPA1B
# HSPA1B
# HSPA1B
# HSPA1B
# ID3
# ID3
# IER3
# IER3
# IER3
# IER3
# IER3
# IER3
# KRT23
# KRT23
# NXN
# NXN
# NXN
# TLCD2
# TLCD2
# YWHAE
# YWHAE

# %%
### 23 MolCell TFs
MolCell_TF_genes = geneset_df['MolCell_23_TF'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(MolCell_TF_genes)) != len(dic.loc[MolCell_TF_genes].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[MolCell_TF_genes].index.tolist():
        if dic.loc[MolCell_TF_genes].index.tolist().count(x) > 1:
            print x

dic.loc[MolCell_TF_genes].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\MolCell_23_TF_genes.xlsx')
# Out:
# genesets don't match! Following genes are duplicates:
# GLIS2
# GLIS2

# %%
### 17 MolCell autoreg 3+3
MolCell_autoreg3_genes = geneset_df['MolCell_17_autoreg_3-3'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(MolCell_autoreg3_genes)) != len(dic.loc[MolCell_autoreg3_genes].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[MolCell_autoreg3_genes].index.tolist():
        if dic.loc[MolCell_autoreg3_genes].index.tolist().count(x) > 1:
            print x

#dic.loc[MolCell_autoreg3_genes].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\MolCell_17_autoreg_3+3_genes.xlsx')
# Out:
# genesets don't match! Following genes are duplicates:
# GLIS2
# GLIS2

# %%
### 7 MolCell autoreg 6+6
MolCell_autoreg6_genes = geneset_df['MolCell_7_autoreg_6-6'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(MolCell_autoreg6_genes)) != len(dic.loc[MolCell_autoreg6_genes].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[MolCell_autoreg6_genes].index.tolist():
        if dic.loc[MolCell_autoreg6_genes].index.tolist().count(x) > 1:
            print x

#dic.loc[MolCell_autoreg6_genes].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\MolCell_7_autoreg_6+6_genes.xlsx')

# %%
### Farnham_dbCoRC_CRC
Farnham_CRC_genes = geneset_df['Farnham_dbCoRC_CRC'].dropna().tolist()

#check if same number of IDs as gene gene names
if len(set(Farnham_CRC_genes)) != len(dic.loc[Farnham_CRC_genes].index.tolist()):
    print "genesets don't match! Following genes are duplicates:"
    for x in dic.loc[Farnham_CRC_genes].index.tolist():
        if dic.loc[Farnham_CRC_genes].index.tolist().count(x) > 1:
            print x

#dic.loc[Farnham_CRC_genes].to_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\Farnham_dbCoRC_CRC_genes.xlsx')

# %%
####################################
#### load in all the gene lists ####
####################################

### preliminary genesets
GenRes_SE_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\GenRes_204_SE_genes.xlsx')
GenRes_TF_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\GenRes_21_TF_genes.xlsx')
GenRes_autoreg3_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\GenRes_14_autoreg_3+3_genes.xlsx')
GenRes_autoreg6_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\GenRes_7_autoreg_6+6_genes.xlsx')
MolCell_SE_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\MolCell_290_SE_genes.xlsx')
MolCell_TF_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\MolCell_23_TF_genes.xlsx')
MolCell_autoreg3_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\MolCell_17_autoreg_3+3_genes.xlsx')
MolCell_autoreg6_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\MolCell_7_autoreg_6+6_genes.xlsx')
Farnham_CRC_genes = pd.read_excel('S:\lab_winter\martin\Mediator_CRC\\old_genesets\\HCT-116\\Farnham_dbCoRC_CRC_genes.xlsx')

# %%
######################################
#### grep genes from DEseq tables ####
######################################
# DEseq2 dataframe
DEseq_TT_1h_df = pd.read_csv('T:\\groups\\lab_winter\\martin\\MJ-20-5_Cramer_lab\\differential.expression.estimates_1h_HCT116.txt', sep="\t")

##### grep CRC genes #####
# use query to parse geneIDs from the DEseq result table. Need to use the '|'.join construct to use geneIDs as REGEX, where some TRxxx annotations have more than on gene_id
GenRes_SE_DEseq_1h = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(GenRes_SE_genes.geneID.tolist()), na=False)]
GenRes_TF_DEseq_1h = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(GenRes_TF_genes.geneID.tolist()), na=False)]
GenRes_autoreg3_DEseq_1h = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(GenRes_autoreg3_genes.geneID.tolist()), na=False)]
GenRes_autoreg6_DEseq_1h = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(GenRes_autoreg6_genes.geneID.tolist()), na=False)]
MolCell_SE_DEseq_1h = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(MolCell_SE_genes.geneID.tolist()), na=False)]
MolCell_TF_DEseq_1h = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(MolCell_TF_genes.geneID.tolist()), na=False)]
MolCell_autoreg3_DEseq_1h = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(MolCell_autoreg3_genes.geneID.tolist()), na=False)]
MolCell_autoreg6_DEseq_1h = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(MolCell_autoreg6_genes.geneID.tolist()), na=False)]
Farnham_CRC_DEseq_1h = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(Farnham_CRC_genes.geneID.tolist()), na=False)]

# %%
####################################
#### plot all sets individually ####
####################################
all_sets = [GenRes_SE_DEseq_1h, GenRes_TF_DEseq_1h, GenRes_autoreg3_DEseq_1h, GenRes_autoreg6_DEseq_1h, MolCell_SE_DEseq_1h, MolCell_TF_DEseq_1h, MolCell_autoreg3_DEseq_1h, MolCell_autoreg6_DEseq_1h, Farnham_CRC_DEseq_1h]
all_set_names = ["GenRes_SE_DEseq_1h", "GenRes_TF_DEseq_1h", "GenRes_autoreg3_DEseq_1h", "GenRes_autoreg6_DEseq_1h", "MolCell_SE_DEseq_1h", "MolCell_TF_DEseq_1h", "MolCell_autoreg3_DEseq_1h", "MolCell_autoreg6_DEseq_1h", "Farnham_CRC_DEseq_1h"]

counter = 0
for geneset in all_sets:
    # make the plots
    plt.close('all')
    sns.set_style('ticks')
    sns.set_context('talk')
    plt.figure(figsize=(8,4.5))

    # for plotting kernel density colormap
    #xy = np.vstack([DEseq_TT_1h_df.baseMean,DEseq_TT_1h_df.log2FoldChange])
    #z = sc.stats.gaussian_kde(xy)(xy)

    # plotting all individual
    plt.scatter(x=DEseq_TT_1h_df.baseMean, y=DEseq_TT_1h_df.log2FoldChange, s=4, c="#b2b2b2", alpha=0.5, edgecolors="none")
    plt.scatter(x=DEseq_TT_1h_df.baseMean[DEseq_TT_1h_df.padj < 0.01], y=DEseq_TT_1h_df.log2FoldChange[DEseq_TT_1h_df.padj < 0.01], s=4, c="#7f7f7f", edgecolors="none")
    plt.scatter(x=geneset.baseMean, y=geneset.log2FoldChange, s=10, c="darkred", edgecolors="none")
    plt.axhline(color="grey",alpha=0.5, linewidth=3)

    # formatting
    plt.xscale('log')
    plt.title('TT-seq DEseq2 - 1h dTAGV-1 \n {0}'.format(all_set_names[counter]))
    plt.xlabel('log10(mean expression)')
    plt.ylabel('log2FC(1h dTAG vs. DMSO)')

    # save
    #plt.savefig(plots_dir + 'TT-seq_1h_DE_scatter\\{0}_1h_scatterplot_final.pdf'.format(all_set_names[counter]), dpi=300)
    #plt.savefig(plots_dir + 'TT-seq_1h_DE_scatter\\{0}_1h_scatterplot_final.png'.format(all_set_names[counter]), dpi=300)
    counter += 1
    plt.show()

# %%
########################
#### make waterfall ####
########################
# significantly downregulated
#ascending = DEseq_TT_1h_df[(DEseq_TT_1h_df.padj < 0.001) & (DEseq_TT_1h_df.log2FoldChange < -0.5)].sort_values(by='log2FoldChange')
# all genes
ascending = DEseq_TT_1h_df.sort_values(by='log2FoldChange')
# add rank column
ascending['rank'] = np.arange(len(ascending.index))

# proxies for grepping the gene sets
GenRes_SE_asc = ascending.gene_id.str.contains('|'.join(GenRes_SE_genes.geneID.tolist()), na=False)
GenRes_TFs_asc = ascending.gene_id.str.contains('|'.join(GenRes_TF_genes.geneID.tolist()), na=False)
GenRes_autoreg3_asc = ascending.gene_id.str.contains('|'.join(GenRes_autoreg3_genes.geneID.tolist()), na=False)
GenRes_autoreg6_asc = ascending.gene_id.str.contains('|'.join(GenRes_autoreg6_genes.geneID.tolist()), na=False)
MolCell_SE_asc = ascending.gene_id.str.contains('|'.join(MolCell_SE_genes.geneID.tolist()), na=False)
MolCell_TFs_asc = ascending.gene_id.str.contains('|'.join(MolCell_TF_genes.geneID.tolist()), na=False)
MolCell_autoreg3_asc = ascending.gene_id.str.contains('|'.join(MolCell_autoreg3_genes.geneID.tolist()), na=False)
MolCell_autoreg6_asc = ascending.gene_id.str.contains('|'.join(MolCell_autoreg6_genes.geneID.tolist()), na=False)
Farnham_CRC_asc = ascending.gene_id.str.contains('|'.join(Farnham_CRC_genes.geneID.tolist()), na=False)

all_sets = [GenRes_SE_asc, GenRes_TFs_asc, GenRes_autoreg3_asc, GenRes_autoreg6_asc, MolCell_SE_asc, MolCell_TFs_asc, MolCell_autoreg3_asc, MolCell_autoreg6_asc, Farnham_CRC_asc]
all_set_names = ["GenRes_SE_asc", "GenRes_TFs_asc", "GenRes_autoreg3_asc", "GenRes_autoreg6_asc", "MolCell_SE_asc", "MolCell_TFs_asc", "MolCell_autoreg3_asc", "MolCell_autoreg6_asc", "Farnham_CRC_asc"]

##### make the plots individually
counter = 0
for geneset in all_sets:
    plt.close('all')
    sns.set_style('ticks')
    sns.set_context('talk')
    plt.figure(figsize=(9,3))

    plt.vlines(x=ascending['rank'], ymin=0, ymax=ascending['log2FoldChange'], linewidth=.25, color='#bababa')
    plt.vlines(x=ascending[geneset]['rank'], ymin=0, ymax=ascending[geneset]['log2FoldChange'], linewidth=.25, color='darkred', label='{0}'.format(all_set_names[counter]))
    #plt.vlines(x=ascending[TF_ascending]['rank'], ymin=0, ymax=ascending[TF_ascending]['log2FoldChange'], linewidth=.25, color='#6c00cc', label='TF_genes')
    #plt.vlines(x=ascending[CRC_ascending]['rank'], ymin=0, ymax=ascending[CRC_ascending]['log2FoldChange'], linewidth=.25, color='black', label='CRC_genes')

    plt.xlabel('rank')
    plt.ylabel('log2FC (1h dTAGV-1 vs. control)')
    plt.title('MED14-dTAG TT-seq 1h vs. DMSO \n {0}'.format(all_set_names[counter]))
    plt.legend(loc=2)


    #plt.savefig(plots_dir + 'TT-seq_1h_DE_waterfall\\{0}_1h_waterfall_final.pdf'.format(all_set_names[counter]), dpi=300)
    #plt.savefig(plots_dir + 'TT-seq_1h_DE_waterfall\\{0}_1h_waterfall_final.png'.format(all_set_names[counter]), dpi=300)
    plt.show()
    counter += 1

# %%
#############################
#### 2h time point below ####
#############################

# %%
######################################
#### grep genes from DEseq tables ####
######################################
# DEseq2 dataframe
DEseq_TT_2h_df = pd.read_csv('T:\\groups\\lab_winter\\martin\\MJ-20-5_Cramer_lab\\differential.expression.estimates_2h_HCT116.txt', sep="\t")

##### grep CRC genes #####
# use query to parse geneIDs from the DEseq result table. Need to use the '|'.join construct to use geneIDs as REGEX, where some TRxxx annotations have more than on gene_id
GenRes_SE_DEseq_2h = DEseq_TT_2h_df[DEseq_TT_2h_df.gene_id.str.contains('|'.join(GenRes_SE_genes.geneID.tolist()), na=False)]
GenRes_TF_DEseq_2h = DEseq_TT_2h_df[DEseq_TT_2h_df.gene_id.str.contains('|'.join(GenRes_TF_genes.geneID.tolist()), na=False)]
GenRes_autoreg3_DEseq_2h = DEseq_TT_2h_df[DEseq_TT_2h_df.gene_id.str.contains('|'.join(GenRes_autoreg3_genes.geneID.tolist()), na=False)]
GenRes_autoreg6_DEseq_2h = DEseq_TT_2h_df[DEseq_TT_2h_df.gene_id.str.contains('|'.join(GenRes_autoreg6_genes.geneID.tolist()), na=False)]
MolCell_SE_DEseq_2h = DEseq_TT_2h_df[DEseq_TT_2h_df.gene_id.str.contains('|'.join(MolCell_SE_genes.geneID.tolist()), na=False)]
MolCell_TF_DEseq_2h = DEseq_TT_2h_df[DEseq_TT_2h_df.gene_id.str.contains('|'.join(MolCell_TF_genes.geneID.tolist()), na=False)]
MolCell_autoreg3_DEseq_2h = DEseq_TT_2h_df[DEseq_TT_2h_df.gene_id.str.contains('|'.join(MolCell_autoreg3_genes.geneID.tolist()), na=False)]
MolCell_autoreg6_DEseq_2h = DEseq_TT_2h_df[DEseq_TT_2h_df.gene_id.str.contains('|'.join(MolCell_autoreg6_genes.geneID.tolist()), na=False)]
Farnham_CRC_DEseq_2h = DEseq_TT_2h_df[DEseq_TT_2h_df.gene_id.str.contains('|'.join(Farnham_CRC_genes.geneID.tolist()), na=False)]

# %%
####################################
#### plot all sets individually ####
####################################
all_sets = [GenRes_SE_DEseq_2h, GenRes_TF_DEseq_2h, GenRes_autoreg3_DEseq_2h, GenRes_autoreg6_DEseq_2h, MolCell_SE_DEseq_2h, MolCell_TF_DEseq_2h, MolCell_autoreg3_DEseq_2h, MolCell_autoreg6_DEseq_2h, Farnham_CRC_DEseq_2h]
all_set_names = ["GenRes_SE_DEseq_2h", "GenRes_TF_DEseq_2h", "GenRes_autoreg3_DEseq_2h", "GenRes_autoreg6_DEseq_2h", "MolCell_SE_DEseq_2h", "MolCell_TF_DEseq_2h", "MolCell_autoreg3_DEseq_2h", "MolCell_autoreg6_DEseq_2h", "Farnham_CRC_DEseq_2h"]

counter = 0
for geneset in all_sets:
    # make the plots
    plt.close('all')
    sns.set_style('ticks')
    sns.set_context('talk')
    plt.figure(figsize=(8,4.5))

    # for plotting kernel density colormap
    #xy = np.vstack([DEseq_TT_2h_df.baseMean,DEseq_TT_2h_df.log2FoldChange])
    #z = sc.stats.gaussian_kde(xy)(xy)

    # plotting all individual
    plt.scatter(x=DEseq_TT_2h_df.baseMean, y=DEseq_TT_2h_df.log2FoldChange, s=4, c="#b2b2b2", alpha=0.5, edgecolors="none")
    plt.scatter(x=DEseq_TT_2h_df.baseMean[DEseq_TT_2h_df.padj < 0.01], y=DEseq_TT_2h_df.log2FoldChange[DEseq_TT_2h_df.padj < 0.01], s=4, c="#7f7f7f", edgecolors="none")
    plt.scatter(x=geneset.baseMean, y=geneset.log2FoldChange, s=10, c="darkred", edgecolors="none")
    plt.axhline(color="grey",alpha=0.5, linewidth=3)

    # formatting
    plt.xscale('log')
    plt.title('TT-seq DEseq2 - 2h dTAGV-1 \n {0}'.format(all_set_names[counter]))
    plt.xlabel('log10(mean expression)')
    plt.ylabel('log2FC(2h dTAG vs. DMSO)')

    # save
    #plt.savefig(plots_dir + 'TT-seq_2h_DE_scatter\\{0}_scatterplot_final.pdf'.format(all_set_names[counter]), dpi=300)
    #plt.savefig(plots_dir + 'TT-seq_2h_DE_scatter\\{0}_scatterplot_final.png'.format(all_set_names[counter]), dpi=300)
    counter += 1
    plt.show()

# %%
########################
#### make waterfall ####
########################
# significantly downregulated
#ascending = DEseq_TT_2h_df[(DEseq_TT_2h_df.padj < 0.001) & (DEseq_TT_2h_df.log2FoldChange < -0.5)].sort_values(by='log2FoldChange')
# all genes
ascending = DEseq_TT_2h_df.sort_values(by='log2FoldChange')
# add rank column
ascending['rank'] = np.arange(len(ascending.index))

# proxies for grepping the gene sets
GenRes_SE_asc = ascending.gene_id.str.contains('|'.join(GenRes_SE_genes.geneID.tolist()), na=False)
GenRes_TFs_asc = ascending.gene_id.str.contains('|'.join(GenRes_TF_genes.geneID.tolist()), na=False)
GenRes_autoreg3_asc = ascending.gene_id.str.contains('|'.join(GenRes_autoreg3_genes.geneID.tolist()), na=False)
GenRes_autoreg6_asc = ascending.gene_id.str.contains('|'.join(GenRes_autoreg6_genes.geneID.tolist()), na=False)
MolCell_SE_asc = ascending.gene_id.str.contains('|'.join(MolCell_SE_genes.geneID.tolist()), na=False)
MolCell_TFs_asc = ascending.gene_id.str.contains('|'.join(MolCell_TF_genes.geneID.tolist()), na=False)
MolCell_autoreg3_asc = ascending.gene_id.str.contains('|'.join(MolCell_autoreg3_genes.geneID.tolist()), na=False)
MolCell_autoreg6_asc = ascending.gene_id.str.contains('|'.join(MolCell_autoreg6_genes.geneID.tolist()), na=False)
Farnham_CRC_asc = ascending.gene_id.str.contains('|'.join(Farnham_CRC_genes.geneID.tolist()), na=False)

all_sets = [GenRes_SE_asc, GenRes_TFs_asc, GenRes_autoreg3_asc, GenRes_autoreg6_asc, MolCell_SE_asc, MolCell_TFs_asc, MolCell_autoreg3_asc, MolCell_autoreg6_asc, Farnham_CRC_asc]
all_set_names = ["GenRes_SE_asc", "GenRes_TFs_asc", "GenRes_autoreg3_asc", "GenRes_autoreg6_asc", "MolCell_SE_asc", "MolCell_TFs_asc", "MolCell_autoreg3_asc", "MolCell_autoreg6_asc", "Farnham_CRC_asc"]

##### make the plots individually
counter = 0
for geneset in all_sets:
    plt.close('all')
    sns.set_style('ticks')
    sns.set_context('talk')
    plt.figure(figsize=(9,3))

    plt.vlines(x=ascending['rank'], ymin=0, ymax=ascending['log2FoldChange'], linewidth=.25, color='#bababa')
    plt.vlines(x=ascending[geneset]['rank'], ymin=0, ymax=ascending[geneset]['log2FoldChange'], linewidth=.25, color='darkred', label='{0}'.format(all_set_names[counter]))
    #plt.vlines(x=ascending[TF_ascending]['rank'], ymin=0, ymax=ascending[TF_ascending]['log2FoldChange'], linewidth=.25, color='#6c00cc', label='TF_genes')
    #plt.vlines(x=ascending[CRC_ascending]['rank'], ymin=0, ymax=ascending[CRC_ascending]['log2FoldChange'], linewidth=.25, color='black', label='CRC_genes')

    plt.xlabel('rank')
    plt.ylabel('log2FC (2h dTAGV-1 vs. control)')
    plt.title('MED14-dTAG TT-seq 2h vs. DMSO \n {0}'.format(all_set_names[counter]))
    plt.legend(loc=2)


    #plt.savefig(plots_dir + 'TT-seq_2h_DE_waterfall\\{0}_2h_waterfall_final.pdf'.format(all_set_names[counter]), dpi=300)
    #plt.savefig(plots_dir + 'TT-seq_2h_DE_waterfall\\{0}_2h_waterfall_final.png'.format(all_set_names[counter]), dpi=300)
    plt.show()
    counter += 1

# %%
# make scatter plot manually (1h)
plt.close('all')
sns.set_style('ticks')
sns.set_context('talk')
plt.figure(figsize=(8,4.5))

# for plotting kernel density colormap
#xy = np.vstack([DEseq_TT_1h_df.baseMean,DEseq_TT_1h_df.log2FoldChange])
#z = sc.stats.gaussian_kde(xy)(xy)

# plotting all individual
plt.axhline(color="#0a0a0a",alpha=0.5, linewidth=1)
plt.axhline(xmin=0.06, xmax=0.98, y=DEseq_TT_1h_df.log2FoldChange.median(), color="#0b0b0b",alpha=0.5, linewidth=2)
#plt.axhline(xmin=0.08, xmax=0.96, y=GenRes_SE_DEseq_1h.log2FoldChange.median(), color="#0050b3",alpha=0.5, linewidth=2)
#plt.axhline(xmin=0.1, xmax=0.94, y=GenRes_autoreg3_DEseq_1h.log2FoldChange.median(), color="#db1d3d",alpha=0.5, linewidth=2)
plt.scatter(x=DEseq_TT_1h_df.baseMean, y=DEseq_TT_1h_df.log2FoldChange, s=4, c="#aaaaaa", alpha=0.5, vmax=0.0005, cmap="bone_r", edgecolors="black", linewidths=0)
plt.scatter(x=DEseq_TT_1h_df.baseMean[DEseq_TT_1h_df.padj < 0.01], y=DEseq_TT_1h_df.log2FoldChange[DEseq_TT_1h_df.padj < 0.01], s=4, c="#7f7f7f", edgecolors="none")
plt.scatter(x=MolCell_autoreg3_DEseq_1h.baseMean, y=MolCell_autoreg3_DEseq_1h.log2FoldChange, s=40, c="#db1d3d", edgecolors="none")
plt.scatter(x=MolCell_SE_DEseq_1h.baseMean, y=MolCell_SE_DEseq_1h.log2FoldChange, s=10, c="#0050b3", edgecolors="none")

plt.scatter(x=DEseq_TT_1h_df[DEseq_TT_1h_df.transcript_id.str.contains('NM_012233')].baseMean, y=DEseq_TT_1h_df[DEseq_TT_1h_df.transcript_id.str.contains('NM_012233')].log2FoldChange, s=20, c="black", edgecolors="none") #rab3gap1
plt.scatter(x=DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('ENSG00000136997', na=False)].baseMean, y=DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('ENSG00000136997', na=False)].log2FoldChange, s=20, c="black", edgecolors="none") #myc
plt.scatter(x=DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('ENSG00000177426', na=False)].baseMean, y=DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('ENSG00000177426', na=False)].log2FoldChange, s=20, c="black", edgecolors="none") #tgif1
plt.scatter(x=DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('ENSG00000166949', na=False)].baseMean, y=DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('ENSG00000166949', na=False)].log2FoldChange, s=20, c="black", edgecolors="none") #smad3
#plt.axhline(color="grey",alpha=0.5, linewidth=2)
#plt.axhline(y=DEseq_TT_1h_df.log2FoldChange.median(), color="#666f96",alpha=0.5, linewidth=2)

# formatting
plt.xscale('log')
plt.xlabel('mean expression')
plt.ylabel('log2FC (1h dTAGV-1 vs. DMSO)')

# save
#plt.savefig(plots_dir + 'TT-seq_1h_DE_scatter\\MolCell_SEs_autoreg3_1h_scatterplot_final.pdf', dpi=300)
#plt.savefig(plots_dir + 'TT-seq_1h_DE_scatter\\MolCell_SEs_autoreg3_1h_scatterplot_final.png', dpi=300)
plt.show()

# %%
# make scatter plot manually (2h)
plt.close('all')
sns.set_style('ticks')
sns.set_context('talk')
plt.figure(figsize=(8,4.5))

# for plotting kernel density colormap
#xy = np.vstack([DEseq_TT_2h_df.baseMean,DEseq_TT_2h_df.log2FoldChange])
#z = sc.stats.gaussian_kde(xy)(xy)

# plotting all individual
plt.axhline(color="#0a0a0a",alpha=0.5, linewidth=1)
plt.axhline(xmin=0.06, xmax=0.98, y=DEseq_TT_2h_df.log2FoldChange.median(), color="#0b0b0b",alpha=0.5, linewidth=2)
#plt.axhline(xmin=0.08, xmax=0.96, y=GenRes_SE_DEseq_2h.log2FoldChange.median(), color="#0050b3",alpha=0.5, linewidth=2)
#plt.axhline(xmin=0.1, xmax=0.94, y=GenRes_autoreg3_DEseq_2h.log2FoldChange.median(), color="#db1d3d",alpha=0.5, linewidth=2)
plt.scatter(x=DEseq_TT_2h_df.baseMean, y=DEseq_TT_2h_df.log2FoldChange, s=4, c="#aaaaaa", alpha=0.5, vmax=0.0005, cmap="bone_r", edgecolors="black", linewidths=0)
plt.scatter(x=DEseq_TT_2h_df.baseMean[DEseq_TT_2h_df.padj < 0.01], y=DEseq_TT_2h_df.log2FoldChange[DEseq_TT_2h_df.padj < 0.01], s=4, c="#7f7f7f", edgecolors="none")
plt.scatter(x=MolCell_autoreg3_DEseq_2h.baseMean, y=MolCell_autoreg3_DEseq_2h.log2FoldChange, s=40, c="#db1d3d", edgecolors="none")
plt.scatter(x=MolCell_SE_DEseq_2h.baseMean, y=MolCell_SE_DEseq_2h.log2FoldChange, s=10, c="#0050b3", edgecolors="none")

#plt.scatter(x=DEseq_TT_2h_df[DEseq_TT_2h_df.transcript_id.str.contains('NM_012233')].baseMean, y=DEseq_TT_2h_df[DEseq_TT_2h_df.transcript_id.str.contains('NM_012233')].log2FoldChange, s=20, c="black", edgecolors="none") #rab3gap1
#plt.scatter(x=DEseq_TT_2h_df[DEseq_TT_2h_df.transcript_id.str.contains('NM_001161660')].baseMean, y=DEseq_TT_2h_df[DEseq_TT_2h_df.transcript_id.str.contains('NM_001161660')].log2FoldChange, s=20, c="black", edgecolors="none") #myb
#plt.axhline(color="grey",alpha=0.5, linewidth=2)
#plt.axhline(y=DEseq_TT_2h_df.log2FoldChange.median(), color="#666f96",alpha=0.5, linewidth=2)

# formatting
plt.xscale('log')
plt.xlabel('mean expression')
plt.ylabel('log2FC (2h dTAGV-1 vs. DMSO)')

# save
#plt.savefig(plots_dir + 'TT-seq_2h_DE_scatter\\MolCell_SEs_autoreg3_2h_scatterplot_final.pdf', dpi=300)
#plt.savefig(plots_dir + 'TT-seq_2h_DE_scatter\\MolCell_SEs_autoreg3_2h_scatterplot_final.png', dpi=300)
plt.show()

# %%
##########################################
#### get genes for GO-term enrichment ####
##########################################

"""This is rather useless => do only GSEA preranked analysis on Broad"""

all_IDs = DEseq_TT_1h_df.gene_id.dropna().tolist()

clean_all = []
for x in all_IDs:
    entry = x.replace('NA','').strip()
    if len(entry.split(" ")) > 1:
        for i in range(len(entry.split(" "))):
            clean_all.append(entry.split(" ")[i])
    else:
        clean_all.append(entry)
clean_all = set(clean_all)
clean_all = pd.DataFrame(list(clean_all), columns=['geneID'])

#clean_all.to_excel("S:\\lab_winter\\martin\\MJ-20-5\\data\\TT-seq_DE_1h_HCT-116_all_ENSEMBL_IDs.xlsx")

# downregulated (padj < 0.001 & log2FC < -0.5)
crude_down = DEseq_TT_1h_df[(DEseq_TT_1h_df.padj < 0.001) & (DEseq_TT_1h_df.log2FoldChange < -0.5)].gene_id.dropna().tolist()

clean_down = []
for x in crude_down:
    entry = x.replace('NA','').strip()
    if len(entry.split(" ")) > 1:
        for i in range(len(entry.split(" "))):
            clean_down.append(entry.split(" ")[i])
    else:
        clean_down.append(entry)
clean_down = set(clean_down)
clean_down = pd.DataFrame(list(clean_down), columns=['geneID'])

#clean_down.to_excel("S:\\lab_winter\\martin\\MJ-20-5\\data\\TT-seq_DE_1h_4825_downregulated.xlsx")

# %%
##### make .rnk file for Broad Genepattern tool "GSEA_preranked" => col1=gene_ID | col2=log2FC

# this is a dictionary of ENSEMBL IDs which have a unique HGNC symbol (but one HGNC symbol can have multiple ENSEMBL IDs!)
ENSEMBL_to_HGNC = pd.read_csv("T:\\groups\\lab_winter\\reference_files\\geneID_dictionaries\\ENSEMBL-Gene-Stable-ID_to_HGNC-Symbol.txt", sep="\t")
ENSEMBL_to_HGNC.columns = ['ENSG', 'HGNC']
ENSEMBL_to_HGNC = ENSEMBL_to_HGNC.drop_duplicates('ENSG').set_index('ENSG', verify_integrity=True) # we lose 7 IDs because they occur more than once



# get log2FC for each geneID
rank_df = DEseq_TT_1h_df[['gene_id','log2FoldChange']].dropna()

#this gets only the downregulated genes
#rank_df = DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('|'.join(clean_down.geneID.tolist()), na=False)][['gene_id','log2FoldChange']]

def strip(str):
    clean = str.replace('NA', '').strip()
    return clean

rank_df['clean_ID'] = rank_df.gene_id.apply(strip)
rank_df = rank_df.loc[:,['clean_ID', 'log2FoldChange']]

# here we explode rows with multiple geneIDs into separate rows => now exactly 1 ID per row, but several IDs occur more than once
rank_df = rank_df.set_index(rank_df.columns.drop('clean_ID',1).tolist()).clean_ID.str.split(' ', expand=True).stack().reset_index().rename(columns={0:'clean_ID'}).loc[:, rank_df.columns]
# remove lines without ENSG ID
rank_df = rank_df[rank_df.clean_ID.str.contains('ENSG')]
# get the HGNC gene name for each ENSEMBL ID
rank_df = rank_df.join(ENSEMBL_to_HGNC, on='clean_ID')
# remove entries without HGNC name
rank_df = rank_df[~rank_df.HGNC.isnull()]

######### here it starts getting arbitrary => first I remove ENSEMBL IDs which don't have an HGNC Symbol; then I'm resolving duplicated geneIDs by retaining those with lowest log2FC; then I arbitrarily keep the first occuring geneID for IDs with the exact same log2FC

# boil down HGNC IDs, retaining the one with minimal log2FC for those which occur more than once
rank_df = rank_df.groupby('HGNC').min()
# kick out HGNCs which have the exact same log2FC; retaining the first occuring HGNC in this case
rank_df = pd.DataFrame(rank_df.log2FoldChange.drop_duplicates())

#rank_df.to_csv("S:\\lab_winter\\martin\\MJ-20-5\\data\\TT-seq_1h_all_HCT-116_17124_log2FC_ranked_for_GSEA.rnk", sep="\t", header=False)#### this file is used as input for Broad's GenePattern tool (GSEApreranked module with standard settings)

# %%
##### perhaps do the GSEA plots here! #####







######

# %%
DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('ENSG00000186834', na=False)]
# Out:
#            chr strand     start       end                type        source  \
# TR19156  chr17      +  45147317  45152101  transcribed_region  REFSEQ_merge
#
#          length       id     baseMean  log2FoldChange     lfcSE      stat  \
# TR19156    4785  TR19156  1074.958333       -0.781097  0.429863 -1.817085
#
#            pvalue      padj          gene_id transcript_id
# TR19156  0.069204  0.180841  ENSG00000186834     NM_006460

# %%
DEseq_TT_1h_df[(DEseq_TT_1h_df.padj < 0.05) & (DEseq_TT_1h_df.log2FoldChange < 0)].sort_values(by="log2FoldChange")
# Out:
#            chr strand      start        end                type        source  \
# TR00673   chr1      +  145281116  145281279  transcribed_region  REFSEQ_merge
# TR10279   chr8      +  127736069  127741434  transcribed_region  REFSEQ_merge
# TR10272   chr8      +  125430321  125438405  transcribed_region  REFSEQ_merge
# TR20159  chr18      +    3411927    3458408  transcribed_region  REFSEQ_merge
# TR10748   chr8      -  127207382  127219268  transcribed_region  REFSEQ_merge
# TR01852   chr1      -  120850819  120850985  transcribed_region  REFSEQ_merge
# TR15349  chr12      -   89347825   89352859  transcribed_region  REFSEQ_merge
# TR09181   chr7      +  121325367  121341104  transcribed_region  REFSEQ_merge
# TR24300   chrX      -   45848074   45851490  transcribed_region  REFSEQ_merge
# TR10196   chr8      +   93916855   93926068  transcribed_region  REFSEQ_merge
# TR05597   chr4      +   74365143   74388760  transcribed_region  REFSEQ_merge
# ...

# %%
DEseq_TT_1h_df[DEseq_TT_1h_df.gene_id.str.contains('ENSG00000230128', na=False)]
# Out:
#           chr strand     start       end                type        source  \
# TR08254  chr6      -  30743199  30744550  transcribed_region  REFSEQ_merge
#
#          length       id     baseMean  log2FoldChange     lfcSE      stat  \
# TR08254    1352  TR08254  1041.958333       -2.593542  0.441941 -5.868523
#
#                pvalue          padj          gene_id transcript_id
# TR08254  4.396957e-09  8.738519e-08  ENSG00000230128     NM_003897

# %%
DEseq_TT_1h_df.describe()
# Out:
#               start           end        length       baseMean  \
# count  2.162900e+04  2.162900e+04  2.162900e+04   21629.000000
# mean   7.455657e+07  7.461773e+07  6.116138e+04    2601.831586
# std    5.534617e+07  5.535199e+07  1.202342e+05    7064.398349
# min    1.155500e+04  1.409000e+04  7.000000e+01       0.083333
# 25%    3.179118e+07  3.186122e+07  9.093000e+03       6.291667
# 50%    6.114160e+07  6.122930e+07  2.392600e+04     236.250000
# 75%    1.107326e+08  1.108703e+08  6.216900e+04    2005.791667
# max    2.489062e+08  2.489191e+08  2.304636e+06  229697.666667
#
#        log2FoldChange         lfcSE          stat         pvalue  \
# count    2.162900e+04  21629.000000  2.162900e+04   2.162900e+04
# mean    -4.466345e-01      0.544287 -1.871064e+00   3.155844e-01
# std      6.240803e-01      0.429507  2.134977e+00   3.653477e-01
# min     -4.565800e+00      0.100019 -2.487535e+01  1.375586e-136
# 25%     -8.107623e-01      0.201200 -3.288795e+00   1.002860e-03
# ...

# %%
MolCell_autoreg3_DEseq_1h.sort_values(by="log2FoldChange")
# Out:
#            chr strand      start        end                type        source  \
# TR10279   chr8      +  127736069  127741434  transcribed_region  REFSEQ_merge
# TR20159  chr18      +    3411927    3458408  transcribed_region  REFSEQ_merge
# TR19311  chr17      +   72121020   72126419  transcribed_region  REFSEQ_merge
# TR19597  chr17      -   17811349   17837011  transcribed_region  REFSEQ_merge
# TR20722  chr19      +   12791496   12793311  transcribed_region  REFSEQ_merge
# TR17211  chr15      +   67065857   67195195  transcribed_region  REFSEQ_merge
# TR14562  chr12      +   53380195   53416442  transcribed_region  REFSEQ_merge
# TR01020   chr1      +  202010562  202017187  transcribed_region  REFSEQ_merge
# TR08683   chr6      -  151364115  151391700  transcribed_region  REFSEQ_merge
# TR17878  chr16      +    4314761    4339597  transcribed_region  REFSEQ_merge
# TR02025   chr1      -  156463721  156500842  transcribed_region  REFSEQ_merge
# ...

# %%
DEseq_TT_1h_df.describe()
# Out:
#               start           end        length       baseMean  \
# count  2.162900e+04  2.162900e+04  2.162900e+04   21629.000000
# mean   7.455657e+07  7.461773e+07  6.116138e+04    2601.831586
# std    5.534617e+07  5.535199e+07  1.202342e+05    7064.398349
# min    1.155500e+04  1.409000e+04  7.000000e+01       0.083333
# 25%    3.179118e+07  3.186122e+07  9.093000e+03       6.291667
# 50%    6.114160e+07  6.122930e+07  2.392600e+04     236.250000
# 75%    1.107326e+08  1.108703e+08  6.216900e+04    2005.791667
# max    2.489062e+08  2.489191e+08  2.304636e+06  229697.666667
#
#        log2FoldChange         lfcSE          stat         pvalue  \
# count    2.162900e+04  21629.000000  2.162900e+04   2.162900e+04
# mean    -4.466345e-01      0.544287 -1.871064e+00   3.155844e-01
# std      6.240803e-01      0.429507  2.134977e+00   3.653477e-01
# min     -4.565800e+00      0.100019 -2.487535e+01  1.375586e-136
# 25%     -8.107623e-01      0.201200 -3.288795e+00   1.002860e-03
# ...

# %%
-1*np.log10(1.938068e-02)
# Out:
# 1.7126309891497138

# %%
DEseq_TT_1h_df
# Out:
#           chr strand      start        end                type        source  \
# TR00001  chr1      +      11874      14409  transcribed_region  REFSEQ_merge
# TR00004  chr1      +     817371     819834  transcribed_region  REFSEQ_merge
# TR00005  chr1      +     827591     859446  transcribed_region  REFSEQ_merge
# TR00006  chr1      +     925741     944581  transcribed_region  REFSEQ_merge
# TR00007  chr1      +     960587     965719  transcribed_region  REFSEQ_merge
# TR00008  chr1      +     966497     975104  transcribed_region  REFSEQ_merge
# TR00009  chr1      +    1013467    1014539  transcribed_region  REFSEQ_merge
# TR00010  chr1      +    1020123    1056119  transcribed_region  REFSEQ_merge
# TR00015  chr1      +    1173906    1197933  transcribed_region  REFSEQ_merge
# TR00016  chr1      +    1232249    1235040  transcribed_region  REFSEQ_merge
# TR00017  chr1      +    1280436    1292029  transcribed_region  REFSEQ_merge
# ...
